# %% [markdown]
# # Misura delle Performance
# ## Animali
# Supponiamo di sapere che esistano in totale `123` tipi di Animali diversi.
#
# *Algorithm AnimalFinder*, tramite machine learning su diversi corpora alla ricerca di Animali e come output restituisce:
#
#     ['Cat', 'Rome', 'Dog', 'Bird', 'Tower']
#
# 1. Calcola la precision, la recall e la f-measure dell'output di *Algorithm AnimalFinder*.
# 1. Identifica i false positive (FP), i true positive (TP)
# 1. Quanti sono i false negative (FN), i true positive (TP) e dai un 2 esempi di ciascuno
#
# ## Regioni d'Italia (20)
#
# Calcola precision e recall dei seguenti?
#
# 1. AlgA: `['Sardinia', 'Tuscany'] `
# 2. AlgB: `['Sardinia', 'Tuscany', 'Sicily', 'Rome'] `
