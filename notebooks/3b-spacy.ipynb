# %% [markdown]
# # NLP  with spacy
#
# pip3 install spacy
# python3 -m spacy download en_core_web_sm

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm") # alternatively, import en_core_web_sm and then: nlp = en_core_web_sm.load()

# %%
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
doc = nlp(text)

# %%
# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['Sebastian Thrun', 'self-driving cars', 'Google', 'few people', 'the company', 'him', 'I', 'you', 'very senior CEOs', 'major American car companies', 'my hand', 'I', 'Thrun', 'an interview', 'Recode']
# Verbs: ['start', 'work', 'drive', 'take', 'tell', 'shake', 'turn', 'talk', 'say']
# Sebastian Thrun PERSON
# Google ORG
# 2007 DATE
# American NORP
# Thrun PERSON
# Recode ORG
# earlier this week DATE

# %%
# !wget -O shakes.txt https://swlab.unica.it/datasets/ocw-datasets/t8.shakespeare.txt
# Out:
# --2024-02-09 11:21:13--  https://swlab.unica.it/datasets/ocw-datasets/t8.shakespeare.txt
# Resolving swlab.unica.it (swlab.unica.it)... 90.147.146.241
# Connecting to swlab.unica.it (swlab.unica.it)|90.147.146.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5458199 (5.2M) [text/plain]
# Saving to: ‘shakes.txt’
#
# shakes.txt          100%[===================>]   5.21M  4.29MB/s    in 1.2s
#
# 2024-02-09 11:21:15 (4.29 MB/s) - ‘shakes.txt’ saved [5458199/5458199]

# %%
# !head -n1000 shakes.txt | tr '\n' ' ' > shakes1000.txt

# %%
#  head -n1000 shakes.txt | tr '\n' ' ' > shakes1000.txt

corpus = open("shakes1000.txt").read()
print(len(corpus))
nlp.max_length = len(corpus)
shakes = nlp(corpus)
# Out:
# 40195

# %%
list(shakes.sents)[10]
# Out:
# THAT CHARGES FOR DOWNLOAD TIME OR FOR MEMBERSHIP.>>

# %%
list(shakes.sents)[501]
# Out:
# I sigh the lack of many a thing I sought,   And with old woes new wail my dear time's waste:

# %%
list(shakes.sents)[502]
# Out:
# Then can I drown an eye (unused to flow)

# %%
sentence = list(shakes.sents)[40]

# %%
for token in sentence:
    print(token)
# Out:
# We
# need
# your
# donations
# more
# than
# ever
# !

# %%
for token in sentence:
    print(token.text, token.lemma_, token.pos_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# We we PRON Xx True True
# need need VERB xxxx True False
# your your PRON xxxx True True
# donations donation NOUN xxxx True False
# more more ADV xxxx True True
# than than ADP xxxx True True
# ever ever ADV xxxx True True
# ! ! PUNCT ! False False
#     SPACE   False False
